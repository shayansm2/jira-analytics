# %%
from DailyVelocityReport import DailyVelocityReport
from DetailedDailyVelocityReport import DetailedDailyVelocityReport
from OutOfPlanReport import OutOfPlanReport

# %%
DailyVelocityReport(squad_names='omc', sprint='05', quarter='4').get()
# Out:
#                                          dev_estimate                        \
# state                                     Code Review developed in_progress
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                 0.0       0.0         8.0
#                      Emel.Mousavi                13.0       5.0         5.0
#                      Mohammadreza.Hasani          0.0       0.0         0.0
#                      Sanaz.Safaei                 0.0       0.0         8.0
#                      Zamani.Mohammad              0.0      80.0        20.0
#                      momen.hamaweisi              0.0      13.0         3.0
#                      unknown                      0.0       0.0         0.0
# app       OMC        Emel.Mousavi                 0.0      34.0        39.0
# backend   OMC                                     0.0       0.0         0.0
#                      Behrad.Fathi                 0.0      14.0         1.0
#                      Emel.Mousavi                 0.0       0.0         0.0
#                      Erfan.soltanloo              0.0       0.0        20.0
#                      Mohammadreza.Hasani          0.0       0.0         3.0
#                      S.ShafieeMoghadam            0.0       0.0         1.0
#                      Sanaz.Safaei                 0.0      67.0       120.0
#                      Zamani.Mohammad             20.0      48.0         8.0
#                      karimi.alireza               0.0       0.0         0.0
#                      momen.hamaweisi              5.0      83.0         8.0
#                      unknown                      0.0       0.0         0.0
#                      z.tahmouresi                 0.0       1.0         0.0
# frontend  OMC        Mohammadreza.Hasani          0.0      15.0        42.0
#                      hamed.taheri                 0.0       0.0        13.0
#                      unknown                      0.0       8.0         0.0
#
#                                                                      \
# state                                    invalid_ticket not_started
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                   0.0         0.0
#                      Emel.Mousavi                   0.0         0.0
#                      Mohammadreza.Hasani            0.0         0.0
#                      Sanaz.Safaei                   0.0        13.0
#                      Zamani.Mohammad               13.0         0.0
#                      momen.hamaweisi                0.0        25.0
#                      unknown                        0.0         0.0
# app       OMC        Emel.Mousavi                  29.0         0.0
# backend   OMC                                       0.0         1.0
#                      Behrad.Fathi                   3.0         0.0
#                      Emel.Mousavi                   0.0         5.0
#                      Erfan.soltanloo                0.0         0.0
#                      Mohammadreza.Hasani            3.0         0.0
#                      S.ShafieeMoghadam              0.0         0.0
#                      Sanaz.Safaei                   8.0         8.0
#                      Zamani.Mohammad               36.0         0.0
#                      karimi.alireza                13.0         0.0
#                      momen.hamaweisi                5.0        15.0
#                      unknown                       28.0         0.0
#                      z.tahmouresi                   0.0         0.0
# frontend  OMC        Mohammadreza.Hasani           18.0         0.0
#                      hamed.taheri                   0.0         0.0
#                      unknown                        2.0         0.0
#
#                                          test_effort                        \
# state                                    Code Review developed in_progress
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                0.0       0.0         8.0
#                      Emel.Mousavi                0.0       0.0         5.0
#                      Mohammadreza.Hasani         0.0       0.0         0.0
#                      Sanaz.Safaei                0.0       0.0         5.0
#                      Zamani.Mohammad             0.0      13.0         0.0
#                      momen.hamaweisi             0.0       0.0         8.0
#                      unknown                     0.0       0.0         0.0
# app       OMC        Emel.Mousavi                0.0       1.0         8.0
# backend   OMC                                    0.0       0.0         0.0
#                      Behrad.Fathi                0.0       0.0         5.0
#                      Emel.Mousavi                0.0       0.0         0.0
#                      Erfan.soltanloo             0.0       0.0        13.0
#                      Mohammadreza.Hasani         0.0       0.0         0.0
#                      S.ShafieeMoghadam           0.0       0.0         0.0
#                      Sanaz.Safaei                0.0      26.0         8.0
#                      Zamani.Mohammad             0.0      25.0         0.0
#                      karimi.alireza              0.0       0.0         0.0
#                      momen.hamaweisi             0.0      33.0         5.0
#                      unknown                     0.0       0.0         0.0
#                      z.tahmouresi                0.0       3.0         0.0
# frontend  OMC        Mohammadreza.Hasani         0.0       5.0        16.0
#                      hamed.taheri                0.0       0.0         0.0
#                      unknown                     0.0       5.0         0.0
#
#                                                                      \
# state                                    invalid_ticket not_started
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                   0.0         0.0
#                      Emel.Mousavi                   0.0         0.0
#                      Mohammadreza.Hasani            0.0         0.0
#                      Sanaz.Safaei                   0.0         0.0
#                      Zamani.Mohammad                5.0         0.0
#                      momen.hamaweisi                0.0         0.0
#                      unknown                       13.0         0.0
# app       OMC        Emel.Mousavi                   5.0         0.0
# backend   OMC                                       0.0         3.0
#                      Behrad.Fathi                   0.0         0.0
#                      Emel.Mousavi                   0.0         5.0
#                      Erfan.soltanloo                0.0         0.0
#                      Mohammadreza.Hasani            8.0         0.0
#                      S.ShafieeMoghadam              0.0         0.0
#                      Sanaz.Safaei                   0.0         8.0
#                      Zamani.Mohammad                0.0         0.0
#                      karimi.alireza                 0.0         0.0
#                      momen.hamaweisi               13.0        20.0
#                      unknown                        8.0         0.0
#                      z.tahmouresi                   0.0         0.0
# frontend  OMC        Mohammadreza.Hasani           18.0         0.0
#                      hamed.taheri                   0.0         0.0
#                      unknown                        0.0         0.0
#
#                                          number_of_tickets            \
# state                                          Code Review developed
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                      0.0       0.0
#                      Emel.Mousavi                      1.0       1.0
#                      Mohammadreza.Hasani               0.0       0.0
#                      Sanaz.Safaei                      0.0       0.0
#                      Zamani.Mohammad                   0.0       5.0
#                      momen.hamaweisi                   0.0       1.0
#                      unknown                           0.0       0.0
# app       OMC        Emel.Mousavi                      0.0       3.0
# backend   OMC                                          0.0       0.0
#                      Behrad.Fathi                      0.0       2.0
#                      Emel.Mousavi                      0.0       0.0
#                      Erfan.soltanloo                   0.0       0.0
#                      Mohammadreza.Hasani               0.0       0.0
#                      S.ShafieeMoghadam                 0.0       0.0
#                      Sanaz.Safaei                      0.0       5.0
#                      Zamani.Mohammad                   1.0       2.0
#                      karimi.alireza                    0.0       0.0
#                      momen.hamaweisi                   1.0       4.0
#                      unknown                           0.0       0.0
#                      z.tahmouresi                      0.0       1.0
# frontend  OMC        Mohammadreza.Hasani               0.0       3.0
#                      hamed.taheri                      0.0       0.0
#                      unknown                           0.0       1.0
#
#                                                                      \
# state                                    in_progress invalid_ticket
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                1.0            0.0
#                      Emel.Mousavi                1.0            0.0
#                      Mohammadreza.Hasani         0.0            0.0
#                      Sanaz.Safaei                1.0            0.0
#                      Zamani.Mohammad             1.0            1.0
#                      momen.hamaweisi             1.0            0.0
#                      unknown                     0.0            4.0
# app       OMC        Emel.Mousavi                3.0            2.0
# backend   OMC                                    0.0            0.0
#                      Behrad.Fathi                1.0            1.0
#                      Emel.Mousavi                0.0            0.0
#                      Erfan.soltanloo             1.0            0.0
#                      Mohammadreza.Hasani         1.0            1.0
#                      S.ShafieeMoghadam           1.0            0.0
#                      Sanaz.Safaei                2.0            1.0
#                      Zamani.Mohammad             1.0            3.0
#                      karimi.alireza              0.0            1.0
#                      momen.hamaweisi             1.0            1.0
#                      unknown                     0.0            5.0
#                      z.tahmouresi                0.0            0.0
# frontend  OMC        Mohammadreza.Hasani         5.0            3.0
#                      hamed.taheri                1.0            0.0
#                      unknown                     0.0            3.0
#
#
# state                                    not_started
# team_name squad_name developed_by
#           OMC        Behrad.Fathi                1.0
#                      Emel.Mousavi                0.0
#                      Mohammadreza.Hasani         1.0
#                      Sanaz.Safaei                2.0
#                      Zamani.Mohammad             1.0
#                      momen.hamaweisi             2.0
#                      unknown                     0.0
# app       OMC        Emel.Mousavi                1.0
# backend   OMC                                    2.0
#                      Behrad.Fathi                2.0
#                      Emel.Mousavi                1.0
#                      Erfan.soltanloo             0.0
#                      Mohammadreza.Hasani         0.0
#                      S.ShafieeMoghadam           2.0
#                      Sanaz.Safaei                1.0
#                      Zamani.Mohammad             0.0
#                      karimi.alireza              0.0
#                      momen.hamaweisi             2.0
#                      unknown                     0.0
#                      z.tahmouresi                0.0
# frontend  OMC        Mohammadreza.Hasani         2.0
#                      hamed.taheri                0.0
#                      unknown                     0.0

# %%
DetailedDailyVelocityReport(squad_names='omc', sprint='05', quarter='4').get()
# Out:
#    squad_name team_name         developed_by           state  \
# 0         OMC                   Behrad.Fathi     in_progress
# 1         OMC                   Behrad.Fathi     not_started
# 2         OMC                   Emel.Mousavi     Code Review
# 3         OMC                   Emel.Mousavi       developed
# 4         OMC                   Emel.Mousavi     in_progress
# 5         OMC            Mohammadreza.Hasani     not_started
# 6         OMC                   Sanaz.Safaei     in_progress
# 7         OMC                   Sanaz.Safaei     not_started
# 8         OMC                Zamani.Mohammad       developed
# 9         OMC                Zamani.Mohammad     in_progress
# 10        OMC                Zamani.Mohammad  invalid_ticket
# 11        OMC                Zamani.Mohammad     not_started
# 12        OMC                momen.hamaweisi       developed
# 13        OMC                momen.hamaweisi     in_progress
# 14        OMC                momen.hamaweisi     not_started
# 15        OMC                        unknown  invalid_ticket
# 16        OMC       app         Emel.Mousavi       developed
# 17        OMC       app         Emel.Mousavi     in_progress
# 18        OMC       app         Emel.Mousavi  invalid_ticket
# 19        OMC       app         Emel.Mousavi     not_started
# 20        OMC   backend                          not_started
# 21        OMC   backend         Behrad.Fathi       developed
# 22        OMC   backend         Behrad.Fathi     in_progress
# 23        OMC   backend         Behrad.Fathi  invalid_ticket
# 24        OMC   backend         Behrad.Fathi     not_started
# 25        OMC   backend         Emel.Mousavi     not_started
# 26        OMC   backend      Erfan.soltanloo     in_progress
# 27        OMC   backend  Mohammadreza.Hasani     in_progress
# 28        OMC   backend  Mohammadreza.Hasani  invalid_ticket
# 29        OMC   backend    S.ShafieeMoghadam     in_progress
# 30        OMC   backend    S.ShafieeMoghadam     not_started
# 31        OMC   backend         Sanaz.Safaei       developed
# 32        OMC   backend         Sanaz.Safaei     in_progress
# 33        OMC   backend         Sanaz.Safaei  invalid_ticket
# 34        OMC   backend         Sanaz.Safaei     not_started
# 35        OMC   backend      Zamani.Mohammad     Code Review
# 36        OMC   backend      Zamani.Mohammad       developed
# 37        OMC   backend      Zamani.Mohammad     in_progress
# 38        OMC   backend      Zamani.Mohammad  invalid_ticket
# 39        OMC   backend       karimi.alireza  invalid_ticket
# 40        OMC   backend      momen.hamaweisi     Code Review
# 41        OMC   backend      momen.hamaweisi       developed
# 42        OMC   backend      momen.hamaweisi     in_progress
# 43        OMC   backend      momen.hamaweisi  invalid_ticket
# 44        OMC   backend      momen.hamaweisi     not_started
# 45        OMC   backend              unknown  invalid_ticket
# 46        OMC   backend         z.tahmouresi       developed
# 47        OMC  frontend  Mohammadreza.Hasani       developed
# 48        OMC  frontend  Mohammadreza.Hasani     in_progress
# 49        OMC  frontend  Mohammadreza.Hasani  invalid_ticket
# 50        OMC  frontend  Mohammadreza.Hasani     not_started
# 51        OMC  frontend         hamed.taheri     in_progress
# 52        OMC  frontend              unknown       developed
# 53        OMC  frontend              unknown  invalid_ticket
#
#     number_of_tickets  dev_estimate  test_effort  \
# 0                   1           8.0          8.0
# 1                   1           0.0          0.0
# 2                   1          13.0          0.0
# 3                   1           5.0          0.0
# 4                   1           5.0          5.0
# 5                   1           0.0          0.0
# 6                   1           8.0          5.0
# 7                   2          13.0          0.0
# 8                   5          80.0         13.0
# 9                   1          20.0          0.0
# 10                  1          13.0          5.0
# 11                  1           0.0          0.0
# 12                  1          13.0          0.0
# 13                  1           3.0          8.0
# 14                  2          25.0          0.0
# 15                  4           0.0         13.0
# 16                  3          34.0          1.0
# 17                  3          39.0          8.0
# 18                  2          29.0          5.0
# 19                  1           0.0          0.0
# 20                  2           1.0          3.0
# 21                  2          14.0          0.0
# 22                  1           1.0          5.0
# 23                  1           3.0          0.0
# 24                  2           0.0          0.0
# 25                  1           5.0          5.0
# 26                  1          20.0         13.0
# 27                  1           3.0          0.0
# 28                  1           3.0          8.0
# 29                  1           1.0          0.0
# 30                  2           0.0          0.0
# 31                  5          67.0         26.0
# 32                  2         120.0          8.0
# 33                  1           8.0          0.0
# 34                  1           8.0          8.0
# 35                  1          20.0          0.0
# 36                  2          48.0         25.0
# 37                  1           8.0          0.0
# 38                  3          36.0          0.0
# 39                  1          13.0          0.0
# 40                  1           5.0          0.0
# 41                  4          83.0         33.0
# 42                  1           8.0          5.0
# 43                  1           5.0         13.0
# 44                  2          15.0         20.0
# 45                  5          28.0          8.0
# 46                  1           1.0          3.0
# 47                  3          15.0          5.0
# 48                  5          42.0         16.0
# 49                  3          18.0         18.0
# 50                  2           0.0          0.0
# 51                  1          13.0          0.0
# 52                  1           8.0          5.0
# 53                  3           2.0          0.0
#
#                                               tickets
# 0       SHOP-8899 : Bug  Shipping fee for plus users
# 1   SHOP-9413 : Canceled system orders - user_rece...
# 2   SHOP-9455 : bug  can not send product in this ...
# 3   SHOP-9414 : Add social widget to the thank you...
# 4   SHOP-8551 : Shipping cost for jet delivery - p...
# 5                      SHOP-8869 : Wallet hint  Front
# 6   SHOP-6913 : [bug]-App-IOS-digikala_shipping pa...
# 7   SHOP-8901 : Bug  Online return filter || SHOP-...
# 8   SHOP-9408 :  time scope test development (fres...
# 9   SHOP-9444 : Deploy and remove old codes - Re F...
# 10  SHOP-9415 : CLONE - [bug]-omc - gift card -iss...
# 11  SHOP-9474 : CLONE - Remove shipping fee for ov...
# 12  SHOP-9432 : Checking the logic of sending noti...
# 13  SHOP-8868 : BUG - OMC - kalabarg - Merge item ...
# 14  SHOP-9334 : CLONE - [bug]-App-Android & IOS- l...
# 15  SHOP-9377 : add index for digipay button || SH...
# 16  SHOP-9297 : CLONE - Displaying deleted items t...
# 17  SHOP-9066 : [bug]-App-Android & IOS- late paym...
# 18  SHOP-9258 : CLONE - [bug]-App-IOS-digikala_shi...
# 19  SHOP-9473 : CLONE - Remove shipping fee for ov...
# 20  SHOP-9434 : [bug]-omc-DataFix-02Q4S05 || SHOP-...
# 21  SHOP-8393 : Cheque BackEnd development - PLP-P...
# 22  SHOP-9110 : [bug]-cheque-save shipment error h...
# 23  SHOP-7073 :  Active addresses for FMCG items  ...
# 24  SHOP-8995 : [bug]-cheque-issue in tooltip - پس...
# 25  SHOP-8333 : [bug]-back-IOS-time scope error in...
# 26  SHOP-6732 : BUG - OMC -  More than 1 shipment ...
# 27  SHOP-8865 : CLONE - [bug]-cheque-view similar ...
# 28  SHOP-8037 : [bug]-kalabarg-save payment- error...
# 29  SHOP-9403 : [Bug]OMC - Duplicate receipt are c...
# 30  SHOP-9313 : BUG - OMC - wrong mass cancellatio...
# 31  SHOP-9154 : [bug] OMC -why the commitment date...
# 32  SHOP-6641 : Error on payment page when have wr...
# 33  SHOP-7628 : Extending reserve time with multip...
# 34  SHOP-7574 : [bug]-web-modify shipment-change a...
# 35                  SHOP-6698 : shipping-promoter-tag
# 36  SHOP-6363 : refactor balance view || SHOP-6246...
# 37  SHOP-9402 : [Bug]OMC - The order status is con...
# 38  SHOP-9278 : [bug]-coupon-deactive cart items i...
# 39         SHOP-8396 : Cheque Cancellation and Refund
# 40  SHOP-9417 : CLONE - OMC- Bug - Checking the lo...
# 41  SHOP-9298 : CLONE - Displaying deleted items t...
# 42  SHOP-8785 : CLONE - [Bug] OMC - Voucher - Why ...
# 43  SHOP-8147 : [bug]-gift card add item-add quantity
# 44  SHOP-7715 : [bug]-Backend-order modification t...
# 45  SHOP-9267 : [Bug] OMC - batch cancellation - W...
# 46              SHOP-9241 : [bug]-omc-DataFix-02Q4S04
# 47  SHOP-7909 : Cheque Frontend development - PLP ...
# 48  SHOP-9157 : shipping cost || SHOP-7750 : Bug-T...
# 49  SHOP-8501 : add plus user boolean in actor of ...
# 50  SHOP-9475 : CLONE - Remove shipping fee for ov...
# 51  SHOP-9184 : Displaying deleted items to the user
# 52  SHOP-8490 : [bug]-production-digikala-gross sh...
# 53  SHOP-9373 : Eliminate categories that do not c...
